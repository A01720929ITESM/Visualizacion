# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('datasets/covid-sanpedro.csv')
df.head(10)

# %%
df.pop('Time ID')

# %%
df.pop('Age Range ID')

# %%
df.head(10)
# Out:
#       Age Range  Sex ID     Sex        Time  Cases  Total Cases  Percentage
# 0    0 a 4 años       1  Hombre  2021-09-05      7           14    0.500000
# 1    0 a 4 años       2   Mujer  2021-09-05      7           14    0.500000
# 2    5 a 9 años       1  Hombre  2021-09-05      9           16    0.562500
# 3    5 a 9 años       2   Mujer  2021-09-05      7           16    0.437500
# 4  10 a 14 años       1  Hombre  2021-09-05      8           14    0.571429
# 5  10 a 14 años       2   Mujer  2021-09-05      6           14    0.428571
# 6  15 a 19 años       1  Hombre  2021-09-05     41           69    0.594203
# 7  15 a 19 años       2   Mujer  2021-09-05     28           69    0.405797
# 8  20 a 24 años       1  Hombre  2021-09-05    122          214    0.570093
# 9  20 a 24 años       2   Mujer  2021-09-05     92          214    0.429907

# %%
sns.boxplot(data=df.loc[:,['Total Cases']])
plt.title('Total Covid Cases')
plt.show()

# %%
df.'Total Cases'.describe()
# Out:
#   File "<ipython-input-26-66726c71f273>", line 1
#     df.'Total Cases'.describe()
#                    ^
# SyntaxError: invalid syntax
